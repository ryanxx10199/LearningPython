# %%
course = " python programming"
print(course.upper())
print (course)
print (course.lower())
print (course.title())
print (course.strip())
print (course.find("pro"))
print (course.replace("p", "r"))
print ("pr" in course)
print ("pr" not in course)
# Out:
#  PYTHON PROGRAMMING
#  python programming
#  python programming
#  Python Programming
# python programming
# 8
#  rython rrogramming
# True
# False
