# %%
first = "Rayyan"
last = "Abdul Majid"

full = first +" "+ last

print(full)
# Out:
# Rayyan Abdul Majid

# %%
first = "Rayyan"
last = "Abdul Majid"

full = f"{first} {last}"

print(full)
# Out:
# Rayyan Abdul Majid
