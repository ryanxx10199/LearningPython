# %%
print(10 + 3)
print(10 - 3)
print(10 * 3)
print(10 / 3)
print(10 // 3) #integer instead of float
print(10 % 3) # remainder
print(10 ** 3) # left to the power of right

x = 10
x = x + 3
# or s
x += 3

print(x)
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 1
# 1000
# 16
